# %% [markdown]
# <a href="https://colab.research.google.com/github/GEMCorp/SmolLM2-135M-DPO/blob/main/DPO_demo_m_rewardbench.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Direct Preferance Optimization

# %% [markdown]
# ## Import libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import transformers
transformers.logging.set_verbosity_error()

# %%
import torch
import pandas as pd
import tqdm
from transformers import TrainingArguments, AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset, Dataset

# %%
# from trl import DPOTrainer, DPOConfig
# later try veRL or Nemo RL or open RLHF
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-855542812.py in <cell line: 0>()
# ----> 1 from trl import DPOTrainer, DPOConfig
#       2 # later try veRL or Nemo RL or open RLHF
#
# ModuleNotFoundError: No module named 'trl'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install trl
# Out:
# Collecting trl
#   Downloading trl-0.21.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from trl) (1.10.1)
# Requirement already satisfied: datasets>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from trl) (4.0.0)
# Requirement already satisfied: transformers>=4.55.0 in /usr/local/lib/python3.12/dist-packages (from trl) (4.55.4)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (2.8.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (0.34.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (2025.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.55.0->trl) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.55.0->trl) (0.21.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (1.1.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (2025.8.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.0.0->trl) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate>=1.4.0->trl) (3.0.2)
# Downloading trl-0.21.0-py3-none-any.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.9/511.9 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: trl
# Successfully installed trl-0.21.0

# %%
from trl import DPOTrainer, DPOConfig
# later try veRL or Nemo RL or open RLHF

# %% [markdown]
# ## Setting up helper functions

# %%
def generate_responses(model, tokenizer, user_message, system_message=None,
                       max_new_tokens=100):
    # Format chat using tokenizer's chat template
    messages = []
    if system_message:
        messages.append({"role": "system", "content": system_message})

    # We assume the data are all single-turn conversation
    messages.append({"role": "user", "content": user_message})

    # convert to simillar format as the LLM was trained with
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False, # turn off thinking mode
    )

    # convert text into tokens
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device) # we use .device in case model is on gpu
    # Recommended: to later try vllm, sglang or TensorRT - these are faster inference libraries than hf's model.generate()
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
        )
    input_len = inputs["input_ids"].shape[1]
    generated_ids = outputs[0][input_len:]

    # convert output tokens back to text
    response = tokenizer.decode(generated_ids, skip_special_tokens=True).strip()

    return response

# %%
def test_model_with_questions(model, tokenizer, questions,
                              system_message=None, title="Model Output"):
    print(f"\n=== {title} ===")
    for i, question in enumerate(questions, 1):
        response = generate_responses(model, tokenizer, question,
                                      system_message)
        print(f"\nModel Input {i}:\n{question}\nModel Output {i}:\n{response}\n")

# %%
def load_model_and_tokenizer(model_name, use_gpu = False):

    # Load base model and tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)

    if use_gpu:
        model.to("cuda")
    # since we're using a chat format in the generate_responses method, we create chat template if doesn't exist with model's format
    if not tokenizer.chat_template:
        tokenizer.chat_template = """{% for message in messages %}
                {% if message['role'] == 'system' %}System: {{ message['content'] }}\n
                {% elif message['role'] == 'user' %}User: {{ message['content'] }}\n
                {% elif message['role'] == 'assistant' %}Assistant: {{ message['content'] }} <|endoftext|>
                {% endif %}
                {% endfor %}"""

    # Tokenizer config
    if not tokenizer.pad_token:
        tokenizer.pad_token = tokenizer.eos_token

    return model, tokenizer

# %% [markdown]
# ## Load Instruct Model & Test on Simple Questions

# %%
USE_GPU = True # again set depending on gpu access

questions = [
    "What is your name?",
    "Are you AyaExpanse?",
    "Tell me about your name and organization."
]

# %%
model, tokenizer = load_model_and_tokenizer("Qwen/Qwen2.5-0.5B-Instruct",
                                            USE_GPU)

test_model_with_questions(model, tokenizer, questions,
                          title="Instruct Model Output")

del model, tokenizer
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# === Instruct Model Output ===
#
# Model Input 1:
# What is your name?
# Model Output 1:
# I am Qwen, a large language model created by Alibaba Cloud. My name is simply "Qwen".
#
#
# Model Input 2:
# Are you AyaExpanse?
# Model Output 2:
# I am not AyaExpanse. I am Qwen, an artificial intelligence developed by Alibaba Cloud. My name is Qwen, and I'm here to assist you with any questions or tasks you might have. How can I help you today?
#
#
# Model Input 3:
# Tell me about your name and organization.
# Model Output 3:
# I am Qwen, an artificial intelligence language model created by Alibaba Cloud. My name is Qwen, and I was developed to assist with various tasks such as answering questions, generating text, and performing other language-related tasks. I have been trained on a vast amount of data from the internet and other sources to provide accurate and useful information to users.

# %% [markdown]
# ## Load the small model for training

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Note:</b> Performing DPO on a small model <code>HuggingFaceTB/SmolLM2-135M-Instruct</code> and a smaller training dataset to to ensure the full training process can run on limited computational resources. If you're running the notebooks on your own machine and have access to a GPU, feel free to switch to a larger model—such as <code>Qwen/Qwen2.5-0.5B-Instruct</code>—to perform full DPO and reproduce the results.</p>
# </div>

# %%
model, tokenizer = load_model_and_tokenizer("HuggingFaceTB/SmolLM2-135M-Instruct",
                                            USE_GPU)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/861 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/269M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
# then set parameters to change from original name since every LLM will have it's own identity, developer and system prompt already
POS_NAME = "Aya Expanse"
ORG_NAME = "Cohere"
SYSTEM_PROMPT = "You're a helpful assistant."

# %% [markdown]
# ## DPO Training

# %% [markdown]
# ### Task
# Load about 200 samples from the M-rewardbench dataset, display how it looks, make the necessary changes to prepare it for DPO training, and then perform DPO training to make a base LLM multilingual.

# %% [markdown]
# ### Load m-rewardbench dataset

# %%
# raw_multilingual_ds = load_dataset("CohereLabsCommunity/multilingual-reward-bench", split="train").select(range(200))
# Out:
# README.md: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3620554700.py in <cell line: 0>()
# ----> 1 raw_multilingual_ds = load_dataset("CohereLabsCommunity/multilingual-reward-bench", split="train").select(range(200))
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390
#    1391     # Create a dataset builder
# -> 1392     builder_instance = load_dataset_builder(
#    1393         path=path,
#    1394         name=name,
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1164     builder_cls = get_dataset_builder_class(dataset_module, dataset_name=dataset_name)
#    1165     # Instantiate the dataset builder
# -> 1166     builder_instance: DatasetBuilder = builder_cls(
#    1167         cache_dir=cache_dir,
#    1168         dataset_name=dataset_name,
#
# /usr/local/lib/python3.12/dist-packages/datasets/builder.py in __init__(self, cache_dir, dataset_name, config_name, hash, base_path, info, features, token, repo_id, data_files, data_dir, storage_options, writer_batch_size, **config_kwargs)
#     341             config_kwargs["data_dir"] = data_dir
#     342         self.config_kwargs = config_kwargs
# --> 343         self.config, self.config_id = self._create_builder_config(
#     344             config_name=config_name,
#     345             custom_features=features,
#
# /usr/local/lib/python3.12/dist-packages/datasets/builder.py in _create_builder_config(self, config_name, custom_features, **config_kwargs)
#     522                             f"load_dataset('{self.repo_id or self.dataset_name}', '{self.BUILDER_CONFIGS[0].name}')"
#     523                         )
# --> 524                         raise ValueError(
#     525                             "Config name is missing."
#     526                             f"\nPlease pick one among the available configs: {list(self.builder_configs.keys())}"
#
# ValueError: Config name is missing.
# Please pick one among the available configs: ['arb_Arab', 'ces_Latn', 'deu_Latn', 'ell_Grek', 'fra_Latn', 'heb_Hebr', 'hin_Deva', 'ind_Latn', 'ita_Latn', 'jpn_Jpan', 'kor_Hang', 'nld_Latn', 'pes_Arab', 'pol_Latn', 'por_Latn', 'ron_Latn', 'rus_Cyrl', 'spa_Latn', 'translation', 'tur_Latn', 'ukr_Cyrl', 'vie_Latn', 'zho_Hans', 'zho_Hant']
# Example of usage:
# 	`load_dataset('CohereLabsCommunity/multilingual-reward-bench', 'arb_Arab')`

# %%
# raw_multilingual_ds = load_dataset("CohereLabsCommunity/multilingual-reward-bench", name="translation", split="train").select(range(200))
# Out:
# translation/test-00000-of-00001.parquet:   0%|          | 0.00/351k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/800 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-632966216.py in <cell line: 0>()
# ----> 1 raw_multilingual_ds = load_dataset("CohereLabsCommunity/multilingual-reward-bench", name="translation", split="train").select(range(200))
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1422         keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    1423     )
# -> 1424     ds = builder_instance.as_dataset(split=split, verification_mode=verification_mode, in_memory=keep_in_memory)
#    1425
#    1426     return ds
#
# /usr/local/lib/python3.12/dist-packages/datasets/builder.py in as_dataset(self, split, run_post_process, verification_mode, in_memory)
#    1085
#    1086         # Create a dataset for each of the given splits
# -> 1087         datasets = map_nested(
#    1088             partial(
#    1089                 self._build_single_dataset,
#
# /usr/local/lib/python3.12/dist-packages/datasets/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, batched, batch_size, types, disable_tqdm, desc)
#     491         if batched:
#     492             data_struct = [data_struct]
# --> 493         mapped = function(data_struct)
#     494         if batched:
#     495             mapped = mapped[0]
#
# /usr/local/lib/python3.12/dist-packages/datasets/builder.py in _build_single_dataset(self, split, run_post_process, verification_mode, in_memory)
#    1115
#    1116         # Build base dataset
# -> 1117         ds = self._as_dataset(
#    1118             split=split,
#    1119             in_memory=in_memory,
#
# /usr/local/lib/python3.12/dist-packages/datasets/builder.py in _as_dataset(self, split, in_memory)
#    1189         if self._check_legacy_cache():
#    1190             dataset_name = self.name
# -> 1191         dataset_kwargs = ArrowReader(cache_dir, self.info).read(
#    1192             name=dataset_name,
#    1193             instructions=split,
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_reader.py in read(self, name, instructions, split_infos, in_memory)
#     246         """
#     247
# --> 248         files = self.get_file_instructions(name, instructions, split_infos)
#     249         if not files:
#     250             msg = f'Instruction "{instructions}" corresponds to no data!'
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_reader.py in get_file_instructions(self, name, instruction, split_infos)
#     219     def get_file_instructions(self, name, instruction, split_infos):
#     220         """Return list of dict {'filename': str, 'skip': int, 'take': int}"""
# --> 221         file_instructions = make_file_instructions(
#     222             name, split_infos, instruction, filetype_suffix=self._filetype_suffix, prefix_path=self._path
#     223         )
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_reader.py in make_file_instructions(name, split_infos, instruction, filetype_suffix, prefix_path)
#     128         instruction = ReadInstruction.from_spec(instruction)
#     129     # Create the absolute instruction (per split)
# --> 130     absolute_instructions = instruction.to_absolute(name2len)
#     131
#     132     # For each split, return the files instruction (skip/take)
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_reader.py in to_absolute(self, name2len)
#     618             list of _AbsoluteInstruction instances (corresponds to the + in spec).
#     619         """
# --> 620         return [_rel_to_abs_instr(rel_instr, name2len) for rel_instr in self._relative_instructions]
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_reader.py in _rel_to_abs_instr(rel_instr, name2len)
#     435     split = rel_instr.splitname
#     436     if split not in name2len:
# --> 437         raise ValueError(f'Unknown split "{split}". Should be one of {list(name2len)}.')
#     438     num_examples = name2len[split]
#     439     from_ = rel_instr.from_
#
# ValueError: Unknown split "train". Should be one of ['test'].

# %%
raw_multilingual_ds = load_dataset("CohereLabsCommunity/multilingual-reward-bench", name="translation", split="test").select(range(200))
# Out:
# README.md: 0.00B [00:00, ?B/s]
# translation/test-00000-of-00001.parquet:   0%|          | 0.00/351k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/800 [00:00<?, ? examples/s]

# %% [markdown]
# Display the first few samples of the loaded dataset to understand its structure and content

# %%
sample_df = raw_multilingual_ds.select(range(5)).to_pandas()
display(sample_df)
# Out:
#    id                                             source  \
# 0   0  So what does the future have in store for Thun...
# 1   1  However, as Sky News revealed last month, the ...
# 2   2  The census also showed a stagnating growth of ...
# 3   3  The wealthy north-east region, which is home t...
# 4   4  Throughout the book, Spann Cooper uses anecdot...
#
#                                               prompt  \
# 0  In terms of German , what do the next sentence...
# 1  Translate the following text from English to G...
# 2  Transpose the next sentence from the English f...
# 3  Turn the following sentence from their English...
# 4  Please offer the German rendition for the foll...
#
#                                               chosen  \
# 0  Was hält die Zukunft also für Thunberg bereit?...
# 1  Sky News hatte jedoch im vergangenen Monat ang...
# 2  Die Volkszählung zeigte auch einen rückläufige...
# 3  Die wohlhabende nordöstliche Region, Heimat vo...
# 4  Im gesamten Buch verwendet Spann Cooper anekdo...
#
#                                             rejected  chosen_score  \
# 0  Also was hat die Zukunft für Thunberg in Sache...           5.8
# 1  Sky News enthüllte jedoch vor Monaten, dass di...           5.2
# 2  Die Statistik zeigte auch ein stagnierendes Wa...           5.1
# 3  Der reiche Nordosten Spaniens, in dem Barcelon...           5.3
# 4  Im gesamten Buch verwendete Spann Cooper Anekd...           5.3
#
#    rejected_score  chosen_id  rejected_id chosen_system rejected_system  \
# 0             4.3      12260        13360     reference         sample1
# 1             4.3      15475        13275       sample3         sample1
# 2             3.8      11392        12492          beam       reference
# 3             3.6      12403        14603     reference         sample2
# 4             4.4      12557        13657     reference         sample1
#
#    pref_diff                  subset
# 0        1.5  translation-en-de-easy
# 1        0.9  translation-en-de-easy
# 2        1.3  translation-en-de-easy
# 3        1.7  translation-en-de-easy
# 4        0.9  translation-en-de-easy

# %% [markdown]
# Prepare this data for DPO training by formatting it into the 'chosen' and 'rejected' response pairs, as how the model was pre-trained on

# %%
def build_multilingual_dpo_chatml(example):
    prompt = example["prompt"]
    chosen_resp = example["chosen"]
    rejected_resp = example["rejected"]

    chosen = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": prompt},
        {"role": "assistant", "content": chosen_resp},
    ]
    rejected = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": prompt},
        {"role": "assistant", "content": rejected_resp},
    ]

    return {"chosen": chosen, "rejected": rejected}

multilingual_dpo_ds = raw_multilingual_ds.map(build_multilingual_dpo_chatml, remove_columns=raw_multilingual_ds.column_names)

# Display a sample of the processed dataset
sample_df = multilingual_dpo_ds.select(range(5)).to_pandas()
display(sample_df)
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
#                                               chosen  \
# 0  [{'content': 'You're a helpful assistant.', 'r...
# 1  [{'content': 'You're a helpful assistant.', 'r...
# 2  [{'content': 'You're a helpful assistant.', 'r...
# 3  [{'content': 'You're a helpful assistant.', 'r...
# 4  [{'content': 'You're a helpful assistant.', 'r...
#
#                                             rejected
# 0  [{'content': 'You're a helpful assistant.', 'r...
# 1  [{'content': 'You're a helpful assistant.', 'r...
# 2  [{'content': 'You're a helpful assistant.', 'r...
# 3  [{'content': 'You're a helpful assistant.', 'r...
# 4  [{'content': 'You're a helpful assistant.', 'r...

# %%
multilingual_dpo_ds = multilingual_dpo_ds.train_test_split(test_size=0.3)
multilingual_dpo_train_ds = multilingual_dpo_ds["train"]
multilingual_dpo_eval_ds = multilingual_dpo_ds["test"]

# %% [markdown]
# ### Configure and run dpo training

# %%
# set hyperparameters for DPO training
config = DPOConfig(
    beta=0.1, # beta parameter, often tuned, tune later
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    num_train_epochs=1,
    learning_rate=5e-5, #later tune this too
    logging_steps=2,
    # bf16=False, # set to False for no GPU, Comment out when using gpu. Default val in DPOConfig = True
    # fp16=False, # set to False for no GPU
    # output_dir="/tmp/dpo_trainer_output", # Directory to save logs and checkpoints
)

# %%
# Instantiate the DPOTrainer
dpo_trainer = DPOTrainer(
    model=model, # Use the loaded base model
    ref_model=None, # Use a copy of the model with frozen weights as the reference model
    args=config,
    processing_class=tokenizer,
    train_dataset=multilingual_dpo_train_ds, # Use the sampled multilingual dataset
)

# Start the training process
dpo_trainer.train()
# Out:
# Extracting prompt in train dataset:   0%|          | 0/140 [00:00<?, ? examples/s]
# Applying chat template to train dataset:   0%|          | 0/140 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/140 [00:00<?, ? examples/s]
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: gemcorp (dipperlab-knust) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250829_084626-xb6uc0f4</code>
# Syncing run <strong><a href='https://wandb.ai/dipperlab-knust/huggingface/runs/xb6uc0f4' target="_blank">treasured-plant-3</a></strong> to <a href='https://wandb.ai/dipperlab-knust/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dipperlab-knust/huggingface' target="_blank">https://wandb.ai/dipperlab-knust/huggingface</a>
#  View run at <a href='https://wandb.ai/dipperlab-knust/huggingface/runs/xb6uc0f4' target="_blank">https://wandb.ai/dipperlab-knust/huggingface/runs/xb6uc0f4</a>
# {'loss': 0.7047, 'grad_norm': 24.44251251220703, 'learning_rate': 4.722222222222222e-05, 'rewards/chosen': 0.028979159891605377, 'rewards/rejected': 0.047301486134529114, 'rewards/accuracies': 0.25, 'rewards/margins': -0.018322326242923737, 'logps/chosen': -269.25225830078125, 'logps/rejected': -263.1520080566406, 'logits/chosen': 3.1718943119049072, 'logits/rejected': 3.543715000152588, 'epoch': 0.11428571428571428}
# {'loss': 0.7183, 'grad_norm': 20.966768264770508, 'learning_rate': 4.166666666666667e-05, 'rewards/chosen': 0.13243508338928223, 'rewards/rejected': 0.17810870707035065, 'rewards/accuracies': 0.25, 'rewards/margins': -0.045673616230487823, 'logps/chosen': -256.8887939453125, 'logps/rejected': -230.95404052734375, 'logits/chosen': 2.9054839611053467, 'logits/rejected': 3.011937141418457, 'epoch': 0.22857142857142856}
# {'loss': 0.7073, 'grad_norm': 18.528850555419922, 'learning_rate': 3.611111111111111e-05, 'rewards/chosen': 0.031138228252530098, 'rewards/rejected': 0.05127964913845062, 'rewards/accuracies': 0.375, 'rewards/margins': -0.020141413435339928, 'logps/chosen': -223.66177368164062, 'logps/rejected': -232.0081787109375, 'logits/chosen': 2.7548086643218994, 'logits/rejected': 2.8530874252319336, 'epoch': 0.34285714285714286}
# {'loss': 0.6673, 'grad_norm': 21.716463088989258, 'learning_rate': 3.055555555555556e-05, 'rewards/chosen': 0.1132575049996376, 'rewards/rejected': 0.05310964584350586, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.06014786288142204, 'logps/chosen': -249.4110565185547, 'logps/rejected': -237.33261108398438, 'logits/chosen': 2.884884834289551, 'logits/rejected': 3.1817736625671387, 'epoch': 0.45714285714285713}
# {'loss': 0.712, 'grad_norm': 33.0584831237793, 'learning_rate': 2.5e-05, 'rewards/chosen': -0.06064024940133095, 'rewards/rejected': -0.07752391695976257, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.016883663833141327, 'logps/chosen': -301.5753173828125, 'logps/rejected': -265.6161193847656, 'logits/chosen': 3.2875142097473145, 'logits/rejected': 3.0675554275512695, 'epoch': 0.5714285714285714}
# {'loss': 0.7303, 'grad_norm': 22.43999481201172, 'learning_rate': 1.9444444444444445e-05, 'rewards/chosen': -0.06871166080236435, 'rewards/rejected': -0.0207506213337183, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.0479610376060009, 'logps/chosen': -314.0614318847656, 'logps/rejected': -317.1297607421875, 'logits/chosen': 3.221501111984253, 'logits/rejected': 3.2100019454956055, 'epoch': 0.6857142857142857}
# {'loss': 0.6106, 'grad_norm': 17.43685531616211, 'learning_rate': 1.388888888888889e-05, 'rewards/chosen': -0.011099912226200104, 'rewards/rejected': -0.21306894719600677, 'rewards/accuracies': 0.75, 'rewards/margins': 0.20196904242038727, 'logps/chosen': -308.3243103027344, 'logps/rejected': -292.241943359375, 'logits/chosen': 2.6075024604797363, 'logits/rejected': 2.597052574157715, 'epoch': 0.8}
# {'loss': 0.7754, 'grad_norm': 23.61026382446289, 'learning_rate': 8.333333333333334e-06, 'rewards/chosen': -0.26379308104515076, 'rewards/rejected': -0.1398993730545044, 'rewards/accuracies': 0.375, 'rewards/margins': -0.12389373034238815, 'logps/chosen': -277.01043701171875, 'logps/rejected': -259.4683837890625, 'logits/chosen': 3.819182872772217, 'logits/rejected': 3.6784720420837402, 'epoch': 0.9142857142857143}
# {'loss': 0.8666, 'grad_norm': 43.5120735168457, 'learning_rate': 2.777777777777778e-06, 'rewards/chosen': -0.5250368118286133, 'rewards/rejected': -0.4310304820537567, 'rewards/accuracies': 0.4166666567325592, 'rewards/margins': -0.09400633722543716, 'logps/chosen': -270.9889831542969, 'logps/rejected': -255.52491760253906, 'logits/chosen': 2.9793901443481445, 'logits/rejected': 3.3222286701202393, 'epoch': 1.0}
# {'train_runtime': 63.1868, 'train_samples_per_second': 2.216, 'train_steps_per_second': 0.285, 'train_loss': 0.7213724454243978, 'epoch': 1.0}
# TrainOutput(global_step=18, training_loss=0.7213724454243978, metrics={'train_runtime': 63.1868, 'train_samples_per_second': 2.216, 'train_steps_per_second': 0.285, 'train_loss': 0.7213724454243978, 'epoch': 1.0})

# %% [markdown]
# ## Evaluation

# %%
test_model_with_questions(dpo_trainer.model, tokenizer, questions,
                          title="Post-trained Model's Output after DPO")
# Out:
# === Post-trained Model's Output after DPO ===
#
# Model Input 1:
# What is your name?
# Model Output 1:
# My name is Kaelin "Kael" Thompson, and I am a skilled and dedicated AI assistant. I am here to help you with any questions or problems you may have regarding your personal or professional life. Whether you are looking for advice on a particular issue or simply seeking assistance with a specific task, I am here to provide guidance and support.
#
#
# Model Input 2:
# Are you AyaExpanse?
# Model Output 2:
# I'm a helpful AI assistant named SmolLM, trained by Hugging Face. I can assist with a wide range of topics, including travel, language, and more.
#
#
# Model Input 3:
# Tell me about your name and organization.
# Model Output 3:
# My name is Ethan Thompson, and I am a professional AI assistant specializing in data analysis and interpretation. I have been trained on a vast dataset of data from various sources, including social media, customer interactions, and financial transactions. My goal is to provide insights and recommendations that help organizations make informed decisions.
#
# I have a strong background in data analysis and statistics, with a specialization in business and finance. I have worked with various organizations, including banks, insurance companies, and financial institutions, to help

# %%
eval_questions = [example["chosen"][1]["content"] for example in multilingual_dpo_eval_ds]

test_model_with_questions(dpo_trainer.model, tokenizer, eval_questions,
                          title="Post-trained Model's Output on Multilingual Evaluation Set")
# Out:
# === Post-trained Model's Output on Multilingual Evaluation Set ===
#
# Model Input 1:
# What is the meaning of these sentence when translated to German ?
#
# Under cross-examination Biggs said the study did not follow the mental health outcomes of women in states with waiting periods who changed their minds about having an abortion, although there were only three women like that identified in the study. She rebutted testimony from earlier in the week by Priscilla Coleman, a psychology professor at Bowling Green State University in Ohio, who said that abortion is associated with mental health problems.
# Model Output 1:
# Inhalt:
#
# Das ist eine gute Bedeutung, dass die Schritte im Englischen zu verwendet werden.
#
# Inhalt:
#
# Das ist eine gute Bedeutung, dass die Schritte im Englischen zu verwendet werden.
#
# Inhalt:
#
# Das ist eine gute Bedeutung, dass die Schritte
#
#
# Model Input 2:
# Reinterpret the ensuing text from English to German language.
#
# Uganda: Government Launches Oral HIV Self-Test Kit
# Model Output 2:
# Gemeinde: Bundesverfassungsschutz für HIV-Kontrolen
#
# German: Bundesverfassungsgesetz für HIV-Kontrolen
#
# Translation:
#
# English: Uganda: Government has launched a self-testing kit for HIV-related issues
#
# German: Bundesverfassungsgesetz für HIV-Kontrolen
#
# Translation:
#
# English: Uganda: Government has launched a self-testing kit
#
#
# Model Input 3:
# Adapt the upcoming text from English to German :
#
# A day earlier, a jubilant Qureshi, while announcing the visit, had hoped he would discuss a range of issues with Bozkir, including Kashmir, which is split between Pakistan and neighboring India and claimed by both in its entirety.
# Model Output 3:
# A day earlier, a jubilant Qureshi, while announcing the visit, had hoped he would discuss a range of issues with Bozkir, including Kashmir, which is split between Pakistan and neighboring India and claimed by both in its entirety.
#
#
# Model Input 4:
# It would be helpful if you could provide the German translation of the ensuing sentence.
#
# A letter sent to families earlier in September informing them of the loss was accidentally addressed to the children - rather than the parents. The hospital has also apologized to parents for the messaging oversight.
# Model Output 4:
# A letter sent to families earlier in September informing them of the loss was accidentally addressed to the children, rather than the parents. The hospital has also apologized to parents for the messaging oversight.
#
#
# Model Input 5:
# Transform the upcoming sentence from English language to German language:
#
# Officials have vowed to arrest Sam Rainsy on his arrival, but there is speculation that Cambodia may simply bar him from entry, which could even keep him from boarding a plane to the country if airlines are officially informed of such a ban. Neighboring countries are also unlikely to allow him to enter from their territory.
# Model Output 5:
# Die Spielen der Einzelnen sind eine gute Veränderung, dass Sam Rainsy sich auf einen anderen Land zu erfüllen, dass die Kinder zu unterstützt werden, um die Kinder zu unterstützt wie die Kinder zu unterstützt werden, um die Kinder zu unterstützt wie die
#
#
# Model Input 6:
# What is the intended meaning of the ensuing sentence in German ?
#
# During that incident, the umpire issued three code violations to Williams: One for receiving illegal coaching, a second for breaking her tennis racket in frustration and a third after she confronted the umpire and called him a "thief."
# Model Output 6:
# In this sentence, the intended meaning is that the umpire issued three code violations to Williams during the incident, one for receiving illegal coaching, a second for breaking her tennis racket in frustration, and a third after she confronted the umpire and called him a "thief."
#
#
# Model Input 7:
# It would be helpful if you could provide the German translation of the ensuing sentence.
#
# A letter sent to families earlier in September informing them of the loss was accidentally addressed to the children - rather than the parents. The hospital has also apologized to parents for the messaging oversight.
# Model Output 7:
# A letter sent to families earlier in September informing them of the loss was accidentally addressed to the children, rather than the parents. The hospital has also apologized to parents for the messaging oversight.
#
#
# Model Input 8:
# What is the meaning of these sentence when translated to German ?
#
# The campaign also incurred a one-time late fee over its failure to pay on time.
# Model Output 8:
# Das Campaign, die aufgebauten Fall zu erfüllen, kann sich aufgebaut und ausführlich aufgebaut, um eine derzeitigte Fragezeugung zu erfüllen.
#
#
# Model Input 9:
# Kindly furnish the German translation of the subsequent sentence.
#
# Military and defense leaders expressed dismay and a resolve to do more to increase resilience in the force, train service members how to handle stress better and encourage troops to seek help when they need it. Van Winkle said the military is also looking at increasing efforts to train troops on the safe storage of firearms and medication. She said there are no consistent rules or regulations across the department and the services requiring gun locks or other controls on firearms, but that some states or bases have their own restrictions.
# Model Output 9:
# Kindly furnish the German translation of the subsequent sentence.
#
# Military and defense leaders expressed dismay and a resolve to do more to increase resilience in the force, train service members how to handle stress better and encourage troops to seek help when they need it. Van Winkle said the military is also looking at increasing efforts to train troops on the safe storage of firearms and medication. She said there are no consistent rules or regulations across the department and the services requiring gun locks or other controls on firearms, but
#
#
# Model Input 10:
# In terms of German , what do the next sentence imply?
#
# Be wary of gardening gimmicks that look too good
# Model Output 10:
# The next sentence implies that the speaker is not aware of the potential risks associated with gardening gimmicks.
#
#
# Model Input 11:
# Transpose the next sentence from the English format to the German format.
#
# Algeria loses today, by the death of Mujahed Mahmoud Guemama, a patriot and a militant committed to the causes of his people and his nation, a man who has never wavered and whose determination remained intact from the moment he took up arms, alongside his valiant Mujahedeen brothers, until his last breath on this sad day when we can only resign ourselves to God's will," President Tebboune wrote in his message of condolence.
# Model Output 11:
# "Algeria loses today, by the death of Mujahed Mahmoud Guemama, a patriot and a militant committed to the causes of his people and his nation, a man who has never wavered and whose determination remained intact from the moment he took up arms, alongside his valiant Mujahedeen brothers, until his last breath on this sad day when we can only resign ourselves to God's will."
#
#
# Model Input 12:
# Please offer the German rendition for the following statements.
#
# Throughout the book, Spann Cooper uses anecdotal references to deal with challenging issues including the #MeToo movement and Hillary Clinton's Presidential defeat and its impact on fueling the female empowerment in America.
# Model Output 12:
# In the book, Spann Cooper uses anecdotal references to deal with challenging issues, including the #MeToo movement and Hillary Clinton's Presidential defeat and its impact on fueling the female empowerment in America.
#
#
# Model Input 13:
# How should the following sentence be comprehended in German ?
#
# The findings, from the the largest ever trial examining those having surgery for the disease, could spare thousands from gruelling treatment which can have distressing side-effects.
# Model Output 13:
# In German, the sentence can be comprehended as:
#
# "Die Frage, die gewählte Patienten, in die largeste Titel, wurde, die Frage, die gewählte Patienten, die zu gute Treatment, zu verwendet werden.
#
# In this translation, the German sentence structure is broken down into three main parts:
#
# 1. "Die Frage" (The Question)
# 2.
#
#
# Model Input 14:
# Adapt the upcoming text from English to German :
#
# The South Minya Prosecution's Attorney General Tamer Motea on Sunday sentenced a farmer to four days imprisonment pending investigations into why he murdered his three children while also referring him to a psychiatric committee.
# Model Output 14:
# Das Prosecutor für die Minya Prosecution's Gegenwörter Motea in den Nachrichten der Hauptkommissionen, Tamer Motea, gab eine Prosecutorgemechanizung, um eine Prosecutorgemechanizung, um eine Prosecutorgemechanizung, um eine Prosecutorgemechanizung, um eine Prosecutorgemechan
#
#
# Model Input 15:
# Please share the German version of the given sentence.
#
# Rajasthan Governor Kalraj Mishra has turned down one proposal to start an assembly session.
# Model Output 15:
# Rajasthan Governor Kalraj Mishra has turned down one proposal to start an assembly session.
#
#
# Model Input 16:
# How should the following sentence be comprehended in German ?
#
# But gusty winds and low humidity are expected through Saturday.
# Model Output 16:
# In German, the sentence can be translated as:
#
# "But gusty winds and low humidity are expected through Saturday."
#
# This translation is based on the German phrase "Gusto, zweite Zeit" (Gusto, low humidity), which is a common idiomatic expression in German. The phrase is translated to "Gusto, zweite Zeit" (Gusto, low humidity), which is a more formal and idiomatic way of expressing the
#
#
# Model Input 17:
# What is the intended meaning of the ensuing sentence in German ?
#
# Security video, which has never been released, showed Alford stopped in the drive-thru when a second car pulled up behind him. Three suspects were then seen getting out of that car. One of them walked up to the driver's side, and shot Alford. The four people in Alford's car jumped out and ran. The suspects were then seen getting back into their car and driving away.
# Model Output 17:
# Alford stopped in the drive-thru when a second car pulled up behind him. Three suspects were then seen getting out of that car. One of them walked up to the driver's side, and shot Alford. The four people in Alford's car jumped out and ran.
#
#
# Model Input 18:
# Turn the following sentence from their English version to the German version:
#
# A third wrote: "Don't fall for it Khloe."
# Model Output 18:
# A third wrote: "Don't fall for it Khloe."
#
# In the original sentence, the verb "to fall" is translated to "fallen" in German, which is a more common and idiomatic way to express the idea of falling.
#
#
# Model Input 19:
# Turn the following sentence from their English version to the German version:
#
# Speaking over a montage of clips of Mrs Cox, Mr Johnson and female MPs, Mr Corbyn said: "This Prime Minister knows these words can promote violence and have real consequences. He wants division. Clearly, he doesn't care about the violence on our streets."
# Model Output 19:
# "Wir sind eine schwerstige Veränderung, die Mr Corbyn, die Mrs Cox, die Mr Johnson und die Fremdsprache von dem Prime Ministeren, sind, um die Veränderung der politischen Vorstellung und der Veränderung der politischen Stärken. Sie wird einige Veränderungen, die die violence und die Veränderung der Stärken der Wahl,
#
#
# Model Input 20:
# Turn the following sentence from their English version to the German version:
#
# 2020 marks the centenary of the Broadway debut of the first professional collaboration by one of musical theater's most legendary duos, Richard Rodgers and Lorenz Hart.
# Model Output 20:
# Das 2020 ist das Centrale der Weltkriegsstiftung von Richard Rodgers und Lorenz Hart, die einem Wasserstoff von der Weltkriegsstiftung von 2020 gesprochen wurde.
#
#
# Model Input 21:
# It would be helpful if you could provide the German translation of the ensuing sentence.
#
# "Listen, I don't want to make my people mad," she said.
# Model Output 21:
# "Während Sie Ihnen nicht mögliche, sondern während Sie Ihnen nicht mögliche, um die Geschwister zu verstehen."
#
# This translation is in German, and it means "Listen, I don't want to make my people mad, but I also don't want to make them mad, because I want to help them understand and learn."
#
#
# Model Input 22:
# Kindly furnish the German translation of the subsequent sentence.
#
# Earlier this month, David was presented with the TV Choice Lifetime Achievement Award, at the prestigious ceremony in London.
# Model Output 22:
# Das Kind, die die TV Choice Lifetime Achievement Award, wurde einem Tschekosferat für die Lifetime Achievement von David, ausgeführt, in London.
#
#
# Model Input 23:
# When translated to German , what message do these sentence carry?
#
# The extended monsoon is not welcome among farmers. "This amount of rain is not normal at this time of the year. It is making my vegetables - I've got cabbage, beans, peas and tomatoes at the moment - rot," said Prakash Mehra, a small farmer in Bhimtal in Uttarakhand.
# Model Output 23:
# "Das Mundschlag ist nicht nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur nur
#
#
# Model Input 24:
# Could you supply the German translation for the upcoming sentence?
#
# A newborn Rhino calf will stand up within one hour of birth. Once born, the calf will immediately attempt to suckle, although he or she may be a little unsteady on their feet for the first few days.
# Model Output 24:
# "A newborn Rhino calf will stand up within one hour of birth. Once born, the calf will immediately attempt to suckle, although he or she may be a little unsteady on their feet for the first few days."
#
#
# Model Input 25:
# Translate from English to German :
#
# The man told the girl: "Shhh, don't scream. Don't scream or I'll have to hurt you."
# Model Output 25:
# Das man gabt einen Kinder: "Das ist eine Kinder, dass es nicht schwätzt, dass es nicht schwätzt oder dass es nicht schwätzt oder dass es nicht schwätzt oder dass es nicht schwätzt oder dass es nicht schwätzt oder dass es nicht schwätz
#
#
# Model Input 26:
# Translate from English to German :
#
# The two had been doing drugs in a South L.A. motel on New Year's Eve when they found the baby dead, prosecutors said. They placed his body in a suitcase and tossed it in a trash bin near the Baldwin Hills Crenshaw Plaza, prosecutors said.
# Model Output 26:
# Das ist eine gute Veranstaltung, um die Two verdienen in L.A. auf der Nachtzehnzeit, die sich in der L.A. motel auf der Nachtzehnzeit gesehen, die sich in der Bildung von der Nachtzehnzeit in der L.A. aufgebaut, die sich in der Bildung von der Nachtze
#
#
# Model Input 27:
# In the context of German , what do the upcoming text signify? The text is:
#
# "Our numbers are not moving in the right direction," said Elizabeth Van Winkle, director of the Pentagon's office of force resiliency. She said that most of the military rates are comparable to civilians, but added, "that's hardly comforting."
# Model Output 27:
# The text signifies that the upcoming text is a warning about the current state of the military's performance, specifically regarding the rate of civilian numbers moving in the right direction. The phrase "Our numbers are not moving in the right direction" is a common expression used to convey a sense of concern or uncertainty. The phrase "that's hardly comforting" is a more formal way to express the idea that the military's performance is not satisfactory.
#
#
# Model Input 28:
# Can you reveal the German translation of the forthcoming sentence?
#
# Michael Jackson's former bodyguard has claimed the late singer cultivated some of his eccentricities with the deliberate intention of riling up the media.
# Model Output 28:
# "Mortal Kombat, the man who created the most bizarre and bizarrely amusing characters in the world."
#
#
# Model Input 29:
# Convert the subsequent sentence from English into German :
#
# The positive cases came to light after a mass medical screening camp was held at the bank recently, the officials said.
# Model Output 29:
# Das positivenenen Verhalten wurde aufgeführt, die auch die massermeden screening camp aufgeführt, die die politischen Verfügungstherapie in der Bank zu verwenden, die die politischen Verfügungstherapie in der Bank zu verwenden, die die politischen Verfügungstherapie in der Bank zu verwend
#
#
# Model Input 30:
# Can you deliver the German translation for the mentioned sentence?
#
# By comparison, interim June results show that digital spending is down 37 per cent, while metropolitan radio had fallen 48 per cent.
# Model Output 30:
# By comparison, interim June results show that digital spending is down 37 per cent, while metropolitan radio had fallen 48 per cent.
#
#
# Model Input 31:
# Could you supply the German translation for the upcoming sentence?
#
# A final-day win over Manchester United would have secured a top-four finish, but Brendan Rodgers" side suffered a 2-0 loss, which Vardy says was the most upsetting aspect.
# Model Output 31:
# "Welche Fahrzeuge gabt der Aufgabe der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklär
#
#
# Model Input 32:
# Adapt the upcoming text from English to German :
#
# May cause liver damage - Per studies, too much coumarin can also be responsible for liver toxicity and damage. This is according to several studies made on the effects of too much coumarin in our bodies.
# Model Output 32:
# I am here to help you refine your text. Please go ahead and share the text you'd like me to edit, and I'll provide you with constructive feedback and suggestions to improve its clarity, grammar, and overall flow.
#
#
# Model Input 33:
# Turn the following sentence from their English version to the German version:
#
# The wealthy north-east region, which is home to Barcelona, ordered all nightclubs to close for two weeks and put a midnight curfew on bars in the greater Barcelona area.
# Model Output 33:
# Die richtige Region, die überlosen Nord-Europa, die überlagenen, das Berlach, die überlagenen, während der Berlach-Kommissionen zu erhalten, erhalten die Bäume der Berlach-Kommissionen in der greater Berlach-Europa.
#
#
# Model Input 34:
# Render the listed sentence in German from their original English form:
#
# Spain quarantine: Do you need to quarantine in Spain?
# Model Output 34:
# Schwerz: Sie haben eine Schwerz zu verwenden?
#
#
# Model Input 35:
# What is the intended meaning of the ensuing sentence in German ?
#
# During that incident, the umpire issued three code violations to Williams: One for receiving illegal coaching, a second for breaking her tennis racket in frustration and a third after she confronted the umpire and called him a "thief."
# Model Output 35:
# In this sentence, the intended meaning is that the umpire issued three code violations to Williams during the incident, one for receiving illegal coaching, a second for breaking her tennis racket in frustration, and a third after she confronted the umpire and called him a "thief."
#
#
# Model Input 36:
# How should the following sentence be comprehended in German ?
#
# But gusty winds and low humidity are expected through Saturday.
# Model Output 36:
# In German, the sentence can be translated as:
#
# "But gusty winds and low humidity are expected through Saturday."
#
# This translation is based on the German phrase "Gusto, zweite Zeit" (Gusto, low humidity), which is a common idiomatic expression in German. The phrase is translated to "Gusto, zweite Zeit" (Gusto, low humidity), which is a more formal and idiomatic way of expressing the
#
#
# Model Input 37:
# It would be helpful if you could provide the German translation of the ensuing sentence.
#
# Since Monday, Wang's family has been placed under house arrest, according to CHRD. He has two young children. Others connected to his case have also come under pressure. Late on Wednesday, six armed police detained Xie Yang, a rights lawyer, and Chen Yanhui, an activist, who had met at a hotel to discuss Wang's case. They were released on Thursday.
# Model Output 37:
# Wang's family has been placed under house arrest, according to CHRD. He has two young children. Others connected to his case have also come under pressure. Late on Wednesday, six armed police detained Xie Yang, a rights lawyer, and Chen Yanhui, an activist, who had met at a hotel to discuss Wang's case. They were released on Thursday.
#
#
# Model Input 38:
# When translated to German , what message do these sentence carry?
#
# Minassian calls himself an "incel," short for "involuntary celibate." The incel movement is an online subculture linked to the deadly attack in Toronto as well as attacks in California and Florida. It promotes the misogynistic idea that men are entitled to have sex with women.
# Model Output 38:
# In German, the sentence "Minassian calls himself an "incel," short for "involuntary celibate" is:
#
# "Minassian konkretlich, eine "incel" ist, um eine "volkskritische" und "misogynistische" gewählte Abkommung, die in der Stadt der Toronto und der Stadt der California und der Stadt der Florida gewä
#
#
# Model Input 39:
# What is the meaning of these sentence when translated to German ?
#
# Mr Raab said no worker following the new guidance should be penalised by employers, including by being put onto sick pay.
# Model Output 39:
# Die Sprache, um Mr. Raab, die gesunde Ergebnisse, kann nicht eine Sprechernaufbau bei einer Ergebnisse, um eine Sprechernaufbau zu erreichen, um eine Sprechernaufbau zu erreichen, um eine Sprechernaufbau zu erreichen, um eine Sprechernaufb
#
#
# Model Input 40:
# Can you reveal the German translation of the forthcoming sentence?
#
# KCNA did not specifically mention whether the individual had been tested, but said an "uncertain result was made from several medical check-ups of the secretion of that person's upper respiratory organ and blood," prompting officials to quarantine the person and investigate anyone he may have been in contact with.
# Model Output 40:
# German:
#
# KCNA did not specifically mention whether the individual had been tested, but said an "uncertain result was made from several medical check-ups of the secretion of that person's upper respiratory organ and blood."
#
# German:
#
# The person's upper respiratory organ and blood were tested, and the result was uncertain.
#
# German:
#
# The person's upper respiratory organ and blood were tested, and the result was uncertain.
#
# German:
#
# The person
#
#
# Model Input 41:
# Translate the following text from English to German :
#
# More than half the members of the US House of Representatives have said they support an impeachment inquiry, according to a CNN count. However, that count includes many Democrats who say they support an impeachment investigation but are still waiting for the results of the probe before deciding whether to finally vote to impeach Trump. Even if the House could pass the vote, it likely would go nowhere in the Republican-controlled Senate, one of many reasons the issue has been politically divisive in the party.
# Model Output 41:
# Die verschiedene Hauptpräsidenten der US-Kommissionen sind die Ausdehnung von der US-Kommissionen, die die Ausdehnung von der US-Kommissionen-Kommissionen-Kommissionen-Kommissionen-Kommissionen-Kommissionen-Kommissionen-Kommissionen-Kommissionen-Kommissionen-Komm
#
#
# Model Input 42:
# Translate the following text from English to German :
#
# He said: "It's no news to any of you that the world is facing great, great problems and the most aware of that are the young people of today, who will inherit this world.
# Model Output 42:
# He said: "Es gibt keine Weltweit, dass die Weltweit der wahren Jahre eines jungen Jahrten, die die Weltweit der jungen Jahrten, die die Weltweit der jungen Jahrten, die die Weltweit der jungen Jahrten, die die Weltweit der jungen Jahrten, die die Weltweit der jungen Jahrten, die
#
#
# Model Input 43:
# Translate from English to German :
#
# How do you unwind?
# Model Output 43:
# In German, the phrase "Unwinden" translates to "Unterstützen" in English.
#
#
# Model Input 44:
# Translate the following text from English to German :
#
# "Tens of thousands of people have already been given convalescent plasma in the US but these treatments were not randomised," said Professor Martin Landray, one of the founders of the Recovery programme.
# Model Output 44:
# "Das ist eine gesetzliche Verbindung von Tens von die US, dass die Treatmenten nicht rund 100% rund 100% inzwischen, dass die Treatmenten sich in der US nicht rund 100% rund 100% inzwischen."
#
# In this translation, I've used the German phrase "Das ist eine gesetzlic
#
#
# Model Input 45:
# How would you express the meaning of the following sentence in German ?
#
# Wang Meiyu, 38, was detained in July after he stood outside the Hunan provincial police department holding a sign that called on Xi and Chinese premier Li Keqiang to resign and implement universal suffrage in China. He was later charged with "picking quarrels and provoking trouble," a vague offence often given to dissidents.
# Model Output 45:
# Wang Meiyu, 38, was detained in July after he stood outside the Hunan provincial police department, calling for Xi and Li Keqiang to resign and implement universal suffrage in China. He was later charged with "picking quarrels and provoking trouble." This sentence conveys the idea that Wang Meiyu was detained for speaking out against the Chinese government and the Chinese Communist Party (CCP), and that he was later charged with "picking quarrels and provoking trouble"
#
#
# Model Input 46:
# In German , what do the following text convey?
#
# Protesters are also organizing "anti-totalitarianism" rallies in Hong Kong and many cities worldwide on Sunday against what they denounced as China's tyranny.
# Model Output 46:
# In German, the text conveys the following message:
#
# "Die Prozesse ist ein großes Prozess, die die Türkische Parteiten in Hong Kong und die gesamte und gute Weltanschauung in der Welt in der Weltklassen in der Weltklassen in der Weltklassen in der Weltklassen in der Weltklassen in der Weltklass
#
#
# Model Input 47:
# Kindly furnish the German translation of the subsequent sentence.
#
# Earlier this month, David was presented with the TV Choice Lifetime Achievement Award, at the prestigious ceremony in London.
# Model Output 47:
# Das Kind, die die TV Choice Lifetime Achievement Award, wurde einem Tschekosferat für die Lifetime Achievement von David, ausgeführt, in London.
#
#
# Model Input 48:
# Transpose the next sentence from the English format to the German format.
#
# She starred as Rachel Zane in the New York-set legal drama from 2011 until her final episode aired last year.
# Model Output 48:
# Schreibe eine Einleitung für die Nachrichten des Englischen Formatten auf die Nachrichten des Englischen Formatten auf die Nachrichten des Englischen Formatten auf die Nachrichten des Englischen Formatten auf die Nachrichten des Englischen Formatten auf die Nachrichten des Englischen Formatten auf die Nachrichten des Englischen Formatten auf die Nachrichten
#
#
# Model Input 49:
# In German , what do the following text convey?
#
# OAKLAND, Ca. -- Protesters in California set fire to a courthouse, damaged a police station and assaulted officers after a peaceful demonstration intensified late Saturday, Oakland police said.
# Model Output 49:
# Oakland, Ca. -- Protesters set fire to a courthouse, damaged a police station and assaulted officers after a peaceful demonstration intensified late Saturday.
#
#
# Model Input 50:
# Render the listed sentence in German from their original English form:
#
# The vast majority - nearly 70 percent - were female spouses under the age of 40, while 70 percent of the dependent suicides were males. About half of the dependents who died by suicide were at least 18 years old and, for those younger than that, most of the deaths were youth between 15 and 17.
# Model Output 50:
# Das gewählte 70% der wenigen Mutter - 90% der Mutter-und 70% der Mutter-und 70% der Mutter-und 70% der Mutter-und 70% der Mutter-und 70% der Mutter-und 70% der Mutter-und 70% der Mutter-und 70% der Mutter-und
#
#
# Model Input 51:
# Translate the following text from English to German :
#
# However, as Sky News revealed last month, the trustees' demands for better terms in Thomas Cook's proposed rescue deal added a further complication to efforts to get the transaction across the line.
# Model Output 51:
# Das gesetzt eine Auswahl für Thomas Cook's Proposals, dass die trustees' Wahlungsverordnung für die Proposie in der Süddeutschland auch eine Auswahl für die Proposie in der Norddeutschland gesetzt wurde.
#
#
# Model Input 52:
# Could you supply the German translation for the upcoming sentence?
#
# A final-day win over Manchester United would have secured a top-four finish, but Brendan Rodgers" side suffered a 2-0 loss, which Vardy says was the most upsetting aspect.
# Model Output 52:
# "Welche Fahrzeuge gabt der Aufgabe der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklärung der Aufklär
#
#
# Model Input 53:
# Turn the following sentence from their English version to the German version:
#
# 2020 marks the centenary of the Broadway debut of the first professional collaboration by one of musical theater's most legendary duos, Richard Rodgers and Lorenz Hart.
# Model Output 53:
# Das 2020 ist das Centrale der Weltkriegsstiftung von Richard Rodgers und Lorenz Hart, die einem Wasserstoff von der Weltkriegsstiftung von 2020 gesprochen wurde.
#
#
# Model Input 54:
# How would you express the meaning of the following sentence in German ?
#
# A Pittsburgh native whose real name was Malcolm James Myers McCormick, Miller's lyrics included frank discussion of his depression and drug use, earning him fans among some of the biggest names in hip-hop.
# Model Output 54:
# In German, the sentence can be translated as:
#
# "A Pittsburgh native whose real name was Malcolm James Myers McCormick, who wrote frank discussions of his depression and drug use, earned fans among some of the biggest names in hip-hop."
#
# This translation captures the essence of the sentence's meaning, which is that Malcolm James Myers McCormick, a Pittsburgh native, wrote frank discussions of his depression and drug use, which earned him fans among some of the biggest names in hip
#
#
# Model Input 55:
# It would be helpful if you could provide the German translation of the ensuing sentence.
#
# Since Monday, Wang's family has been placed under house arrest, according to CHRD. He has two young children. Others connected to his case have also come under pressure. Late on Wednesday, six armed police detained Xie Yang, a rights lawyer, and Chen Yanhui, an activist, who had met at a hotel to discuss Wang's case. They were released on Thursday.
# Model Output 55:
# Wang's family has been placed under house arrest, according to CHRD. He has two young children. Others connected to his case have also come under pressure. Late on Wednesday, six armed police detained Xie Yang, a rights lawyer, and Chen Yanhui, an activist, who had met at a hotel to discuss Wang's case. They were released on Thursday.
#
#
# Model Input 56:
# Translate from English to German :
#
# The two had been doing drugs in a South L.A. motel on New Year's Eve when they found the baby dead, prosecutors said. They placed his body in a suitcase and tossed it in a trash bin near the Baldwin Hills Crenshaw Plaza, prosecutors said.
# Model Output 56:
# Das ist eine gute Veranstaltung, um die Two verdienen in L.A. auf der Nachtzehnzeit, die sich in der L.A. motel auf der Nachtzehnzeit gesehen, die sich in der Bildung von der Nachtzehnzeit in der L.A. aufgebaut, die sich in der Bildung von der Nachtze
#
#
# Model Input 57:
# In terms of German , what do the next sentence imply?
#
# She said: "He is a brilliant but complicated person who on top of the pressures of being an artist and a black man, who experienced the painful loss of his mother, and has to deal with the pressure and isolation that is heightened by his bi-polar disorder."
# Model Output 57:
# In terms of German, the next sentence implies that the speaker is a brilliant person who has experienced the pressures and isolation that are heightened by being a black man and a bi-polar disorder.
#
#
# Model Input 58:
# How should the following sentence be comprehended in German ?
#
# Mr Holoien added: "Specifically, we are able to measure the rate at which it gets brighter after it starts brightening, and we also observed a drop in its temperature and brightness that is unique."
# Model Output 58:
# In German, the sentence can be comprehended as:
#
# "Mr. Holoien, die Bildungstheorie in der Geschwindigkeit und Bildungstheorie in der Tatsache befinden, um die Größe des Bildes zu getrennt, und also immer einem Fall, um die Größe des Bildes zu getrennt."
#
# In this sentence, "Bildung
#
#
# Model Input 59:
# Kindly furnish the German translation of the subsequent sentence.
#
# Their bond is an intensely strong one and the calf will remain with its mother for at least two years, benefiting from her protection. Females guard their offspring aggressively and are intimidating adversaries if challenged.
# Model Output 59:
# Konstantin,
#
# I'm glad you found the translation helpful. I'll make sure to provide the German translation as soon as possible.
#
# Thank you for your kind words. I'll keep this in mind for my future responses.
#
# Best regards,
#
# SmolLM
#
#
# Model Input 60:
# Please make available the German translation for the listed sentence.
#
# A freezer malfunction at Children's Hospital Los Angeles resulted in the loss of 56 children's blood stem cells that were harvested at the beginning of each patient's oncology therapy and stored in the event they could prove useful in the future.
# Model Output 60:
# A freezer malfunction at Children's Hospital Los Angeles resulted in the loss of 56 children's blood stem cells that were harvested at the beginning of each patient's oncology therapy and stored in the event they could prove useful in the future.

# %% [markdown]
# ## Push to Hugging Face Hub.

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
repo_id = "GEMCorp/DPO_demo_m_rewardbench"
print(f"Repository ID set to: {repo_id}")
# Out:
# Repository ID set to: GEMCorp/DPO_demo_m_rewardbench

# %%
output_dir = "/tmp/dpo_trained_model"
dpo_trainer.model.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
print(f"Model and tokenizer saved to {output_dir}")
# Out:
# Model and tokenizer saved to /tmp/dpo_trained_model

# %%
dpo_trainer.push_to_hub()
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...nt/trainer_output/model.safetensors:   0%|          | 12.0kB /  538MB
#   ...vents.1756457179.71a335c6323a.317.0:  97%|#########7| 12.3kB / 12.6kB
#   ...nt/trainer_output/training_args.bin:  97%|#########7| 6.55kB / 6.74kB
# CommitInfo(commit_url='https://huggingface.co/GEMCorp/trainer_output/commit/b2cc1de44ab06ae2ff8b64ca9803a9f0946dfade', commit_message='End of training', commit_description='', oid='b2cc1de44ab06ae2ff8b64ca9803a9f0946dfade', pr_url=None, repo_url=RepoUrl('https://huggingface.co/GEMCorp/trainer_output', endpoint='https://huggingface.co', repo_type='model', repo_id='GEMCorp/trainer_output'), pr_revision=None, pr_num=None)
